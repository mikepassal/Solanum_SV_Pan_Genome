# %%
import pandas as pd 
import os

# %%
list_of_files = os.listdir('/data/passala/Collaborator_Data/Hagai_zach_circadian/RNA_data')

# %%
tester = '20'
int(tester)
# Out:
# 20

# %%
def decode_file_name(file_name):
    parts = file_name.split('_')
    species = parts[4]
    replicate = parts[5]
    time_point = parts[6]
    if int(time_point) <12:
        time_point = time_point + 'am'
    elif int(time_point) >= 12:
        time_point = time_point + 'pm'
    else: 
        raise Exception("No time point found in file name")

    summary_dictionary = {'species': species, 'replicate': replicate, 'time_point': time_point}
    return summary_dictionary

# %%
list_of_files[0:3]
# Out:
# ['HT1004_Solanum_SP5G_A01_Spim_1_6_10481877_232FCWLT3_L1_R2.fastq',
#  'HT1004_Solanum_SP5G_A02_Spim_2_6_10481877_232FCWLT3_L1_R1.fastq',
#  'HT1004_Solanum_SP5G_A02_Spim_2_6_10481877_232FCWLT3_L1_R2.fastq']

# %%
unique_file_prefixes = pd.Series(list_of_files).str.split('L1').str[0]

# %%
genome_locations = pd.read_csv('/data/passala/Generated_Tables/Temp_junk/list_of_genome_fastas.csv', sep='\t')
genome_locations
# Out:
#                Species Abbreviation  \
# 0  S. pimpinelifollium         Spim
# 1      S. lycopersicum          M82
# 2           S. anguivi         Sang
# 3      S. aethiopicum          Saet
# 4       S. aet (SC103)        SC103
# 5      S. cleistogamum         Scle
# 6      S. prinophyllum         Spri
# 7            P. grisea         Pgri
#
#                                         Genome Fasta  \
# 0  /data/passala/Genomes/Hagai_alignment_genomes/...
# 1  /data/passala/Genomes/Solanum_lycopersicum_4_0...
# 2  /data/passala/Genomes/Hagai_alignment_genomes/...
# 3  /data/passala/Genomes/Hagai_alignment_genomes/...
# 4  /data/passala/Genomes/Hagai_alignment_genomes/...
# 5  /data/passala/Genomes/Hagai_alignment_genomes/...
# 6  /data/passala/Genomes/Hagai_alignment_genomes/...
# 7  /data/passala/Genomes/Hagai_alignment_genomes/...
#
#                                    Genome Annotation  \
# 0  /data/passala/Genomes/Hagai_alignment_genomes/...
# 1  /data/passala/Genomes/Solanum_lycopersicum_4_0...
# 2  /data/passala/Genomes/Hagai_alignment_genomes/...
# 3  /data/passala/Genomes/Hagai_alignment_genomes/...
# 4  /data/passala/Genomes/Hagai_alignment_genomes/...
# 5  /data/passala/Genomes/Hagai_alignment_genomes/...
# 6  /data/passala/Genomes/Hagai_alignment_genomes/...
# 7  /data/passala/Genomes/Hagai_alignment_genomes/...
#
#                                        Genome Folder
# 0  /data/passala/Genomes/Hagai_alignment_genomes/...
# 1     /data/passala/Genomes/Solanum_lycopersicum_4_0
# 2  /data/passala/Genomes/Hagai_alignment_genomes/...
# 3  /data/passala/Genomes/Hagai_alignment_genomes/...
# 4  /data/passala/Genomes/Hagai_alignment_genomes/...
# 5  /data/passala/Genomes/Hagai_alignment_genomes/...
# 6  /data/passala/Genomes/Hagai_alignment_genomes/...
# 7  /data/passala/Genomes/Hagai_alignment_genomes/...

# %%
genome_locations_sans_tomato = genome_locations.drop(index= 1)
genome_locations_sans_tomato
# Out:
#                Species Abbreviation  \
# 0  S. pimpinelifollium         Spim
# 2           S. anguivi         Sang
# 3      S. aethiopicum          Saet
# 4       S. aet (SC103)        SC103
# 5      S. cleistogamum         Scle
# 6      S. prinophyllum         Spri
# 7            P. grisea         Pgri
#
#                                         Genome Fasta  \
# 0  /data/passala/Genomes/Hagai_alignment_genomes/...
# 2  /data/passala/Genomes/Hagai_alignment_genomes/...
# 3  /data/passala/Genomes/Hagai_alignment_genomes/...
# 4  /data/passala/Genomes/Hagai_alignment_genomes/...
# 5  /data/passala/Genomes/Hagai_alignment_genomes/...
# 6  /data/passala/Genomes/Hagai_alignment_genomes/...
# 7  /data/passala/Genomes/Hagai_alignment_genomes/...
#
#                                    Genome Annotation  \
# 0  /data/passala/Genomes/Hagai_alignment_genomes/...
# 2  /data/passala/Genomes/Hagai_alignment_genomes/...
# 3  /data/passala/Genomes/Hagai_alignment_genomes/...
# 4  /data/passala/Genomes/Hagai_alignment_genomes/...
# 5  /data/passala/Genomes/Hagai_alignment_genomes/...
# 6  /data/passala/Genomes/Hagai_alignment_genomes/...
# 7  /data/passala/Genomes/Hagai_alignment_genomes/...
#
#                                        Genome Folder
# 0  /data/passala/Genomes/Hagai_alignment_genomes/...
# 2  /data/passala/Genomes/Hagai_alignment_genomes/...
# 3  /data/passala/Genomes/Hagai_alignment_genomes/...
# 4  /data/passala/Genomes/Hagai_alignment_genomes/...
# 5  /data/passala/Genomes/Hagai_alignment_genomes/...
# 6  /data/passala/Genomes/Hagai_alignment_genomes/...
# 7  /data/passala/Genomes/Hagai_alignment_genomes/...

# %%
# Generate Genome Indexes
for file in genome_locations_sans_tomato.iterrows():
    fasta = file[1]['Genome Fasta']
    annotation = file[1]['Genome Annotation']
    directory = file[1]['Genome Folder']
    ! /data/passala/Module_paper_data/Populus_vs_glycine_drought/STAR  --runThreadN 30 --runMode genomeGenerate --genomeDir {directory} --genomeFastaFiles {fasta} --sjdbGTFfile {annotation} --sjdbOverhang 100 --genomeSAindexNbases 13
# Out:
# Jul 04 09:27:35 ..... started STAR run
# Jul 04 09:27:35 ... starting to generate Genome files
# Jul 04 09:27:48 ... starting to sort Suffix Array. This may take a long time...
# Jul 04 09:27:51 ... sorting Suffix Array chunks and saving them to disk...
# Jul 04 09:29:29 ... loading chunks from disk, packing SA...
# Jul 04 09:29:55 ... finished generating suffix array
# Jul 04 09:29:55 ... generating Suffix Array index
# Jul 04 09:30:38 ... completed Suffix Array index
# Jul 04 09:30:38 ..... processing annotations GTF
# Jul 04 09:30:41 ..... inserting junctions into the genome indices
# Jul 04 09:31:25 ... writing Genome to disk ...
# Jul 04 09:31:27 ... writing Suffix Array to disk ...
# Jul 04 09:31:34 ... writing SAindex to disk
# Jul 04 09:31:35 ..... finished successfully
# Jul 04 09:31:35 ..... started STAR run
# Jul 04 09:31:35 ... starting to generate Genome files
# Jul 04 09:31:54 ... starting to sort Suffix Array. This may take a long time...
# Jul 04 09:31:59 ... sorting Suffix Array chunks and saving them to disk...
# Jul 04 09:35:05 ... loading chunks from disk, packing SA...
# Jul 04 09:35:40 ... finished generating suffix array
# Jul 04 09:35:40 ... generating Suffix Array index
# Jul 04 09:36:31 ... completed Suffix Array index
# Jul 04 09:36:31 ..... processing annotations GTF
# Jul 04 09:36:33 ..... inserting junctions into the genome indices
# Jul 04 09:37:26 ... writing Genome to disk ...
# Jul 04 09:37:27 ... writing Suffix Array to disk ...
# Jul 04 09:37:40 ... writing SAindex to disk
# Jul 04 09:37:42 ..... finished successfully
# Jul 04 09:37:42 ..... started STAR run
# Jul 04 09:37:42 ... starting to generate Genome files
# Jul 04 09:38:01 ... starting to sort Suffix Array. This may take a long time...
# Jul 04 09:38:05 ... sorting Suffix Array chunks and saving them to disk...
# Jul 04 09:40:46 ... loading chunks from disk, packing SA...
# Jul 04 09:41:21 ... finished generating suffix array
# Jul 04 09:41:21 ... generating Suffix Array index
# Jul 04 09:42:19 ... completed Suffix Array index
# Jul 04 09:42:19 ..... processing annotations GTF
# Jul 04 09:42:20 ..... inserting junctions into the genome indices
# Jul 04 09:43:12 ... writing Genome to disk ...
# Jul 04 09:43:13 ... writing Suffix Array to disk ...
# Jul 04 09:43:31 ... writing SAindex to disk
# Jul 04 09:43:32 ..... finished successfully
# Jul 04 09:43:33 ..... started STAR run
# Jul 04 09:43:33 ... starting to generate Genome files
# Jul 04 09:43:52 ... starting to sort Suffix Array. This may take a long time...
# Jul 04 09:43:56 ... sorting Suffix Array chunks and saving them to disk...
# Jul 04 09:46:48 ... loading chunks from disk, packing SA...
# Jul 04 09:47:23 ... finished generating suffix array
# Jul 04 09:47:23 ... generating Suffix Array index
# Jul 04 09:48:23 ... completed Suffix Array index
# Jul 04 09:48:23 ..... processing annotations GTF
# Jul 04 09:48:25 ..... inserting junctions into the genome indices
# Jul 04 09:49:19 ... writing Genome to disk ...
# Jul 04 09:49:20 ... writing Suffix Array to disk ...
# Jul 04 09:51:18 ... writing SAindex to disk
# Jul 04 09:51:20 ..... finished successfully
# Jul 04 09:51:23 ..... started STAR run
# Jul 04 09:51:23 ... starting to generate Genome files
# Jul 04 09:51:40 ... starting to sort Suffix Array. This may take a long time...
# Jul 04 09:51:44 ... sorting Suffix Array chunks and saving them to disk...
# Jul 04 09:53:49 ... loading chunks from disk, packing SA...
# Jul 04 09:54:19 ... finished generating suffix array
# Jul 04 09:54:19 ... generating Suffix Array index
# Jul 04 09:55:18 ... completed Suffix Array index
# Jul 04 09:55:18 ..... processing annotations GTF
# Jul 04 09:55:21 ..... inserting junctions into the genome indices
# Jul 04 09:56:07 ... writing Genome to disk ...
# Jul 04 09:56:19 ... writing Suffix Array to disk ...
# Jul 04 09:56:31 ... writing SAindex to disk
# Jul 04 09:56:32 ..... finished successfully
# Jul 04 09:56:33 ..... started STAR run
# Jul 04 09:56:33 ... starting to generate Genome files
# Jul 04 09:56:53 ... starting to sort Suffix Array. This may take a long time...
# Jul 04 09:56:58 ... sorting Suffix Array chunks and saving them to disk...
# Jul 04 10:00:47 ... loading chunks from disk, packing SA...
# Jul 04 10:01:25 ... finished generating suffix array
# Jul 04 10:01:25 ... generating Suffix Array index
# Jul 04 10:02:35 ... completed Suffix Array index
# Jul 04 10:02:35 ..... processing annotations GTF
# Jul 04 10:02:37 ..... inserting junctions into the genome indices
# Jul 04 10:03:28 ... writing Genome to disk ...
# Jul 04 10:03:30 ... writing Suffix Array to disk ...
# Jul 04 10:03:46 ... writing SAindex to disk
# Jul 04 10:03:48 ..... finished successfully
# Jul 04 10:03:48 ..... started STAR run
# Jul 04 10:03:48 ... starting to generate Genome files
# Jul 04 10:04:12 ... starting to sort Suffix Array. This may take a long time...
# Jul 04 10:04:17 ... sorting Suffix Array chunks and saving them to disk...
# Jul 04 10:07:46 ... loading chunks from disk, packing SA...
# Jul 04 10:08:31 ... finished generating suffix array
# Jul 04 10:08:31 ... generating Suffix Array index
# Jul 04 10:09:38 ... completed Suffix Array index
# Jul 04 10:09:38 ..... processing annotations GTF
# Jul 04 10:09:40 ..... inserting junctions into the genome indices
# Jul 04 10:10:35 ... writing Genome to disk ...
# Jul 04 10:10:38 ... writing Suffix Array to disk ...
# Jul 04 10:10:52 ... writing SAindex to disk
# Jul 04 10:10:54 ..... finished successfully

# %%
list_of_unique_file_prefixes = unique_file_prefixes.unique().tolist()

# %%
file_location = '/data/passala/Collaborator_Data/Hagai_zach_circadian/RNA_data/'
processed_data_location = '/data/passala/Collaborator_Data/Hagai_zach_circadian/processed_RNA_data/'

# %%
genome_locations
# Out:
#                Species Abbreviation  \
# 0  S. pimpinelifollium         Spim
# 1      S. lycopersicum          M82
# 2           S. anguivi         Sang
# 3      S. aethiopicum          Saet
# 4       S. aet (SC103)        SC103
# 5      S. cleistogamum         Scle
# 6      S. prinophyllum         Spri
# 7            P. grisea         Pgri
#
#                                         Genome Fasta  \
# 0  /data/passala/Genomes/Hagai_alignment_genomes/...
# 1  /data/passala/Genomes/Solanum_lycopersicum_4_0...
# 2  /data/passala/Genomes/Hagai_alignment_genomes/...
# 3  /data/passala/Genomes/Hagai_alignment_genomes/...
# 4  /data/passala/Genomes/Hagai_alignment_genomes/...
# 5  /data/passala/Genomes/Hagai_alignment_genomes/...
# 6  /data/passala/Genomes/Hagai_alignment_genomes/...
# 7  /data/passala/Genomes/Hagai_alignment_genomes/...
#
#                                    Genome Annotation  \
# 0  /data/passala/Genomes/Hagai_alignment_genomes/...
# 1  /data/passala/Genomes/Solanum_lycopersicum_4_0...
# 2  /data/passala/Genomes/Hagai_alignment_genomes/...
# 3  /data/passala/Genomes/Hagai_alignment_genomes/...
# 4  /data/passala/Genomes/Hagai_alignment_genomes/...
# 5  /data/passala/Genomes/Hagai_alignment_genomes/...
# 6  /data/passala/Genomes/Hagai_alignment_genomes/...
# 7  /data/passala/Genomes/Hagai_alignment_genomes/...
#
#                                        Genome Folder
# 0  /data/passala/Genomes/Hagai_alignment_genomes/...
# 1     /data/passala/Genomes/Solanum_lycopersicum_4_0
# 2  /data/passala/Genomes/Hagai_alignment_genomes/...
# 3  /data/passala/Genomes/Hagai_alignment_genomes/...
# 4  /data/passala/Genomes/Hagai_alignment_genomes/...
# 5  /data/passala/Genomes/Hagai_alignment_genomes/...
# 6  /data/passala/Genomes/Hagai_alignment_genomes/...
# 7  /data/passala/Genomes/Hagai_alignment_genomes/...

# %%
species
# Out:
# 'Spim'

# %%
genome_locations.loc[genome_locations['Abbreviation'] == species]['Genome Folder'].item()
# Out:
# '/data/passala/Genomes/Hagai_alignment_genomes/Solanum_pimpinelifollium'

# %%
list_of_unique_file_prefixes
# Out:
# ['HT1004_Solanum_SP5G_A01_Spim_1_6_10481877_232FCWLT3_',
#  'HT1004_Solanum_SP5G_A02_Spim_2_6_10481877_232FCWLT3_',
#  'HT1004_Solanum_SP5G_A03_Spim_3_6_10481877_232FCWLT3_',
#  'HT1004_Solanum_SP5G_A04_Spim_1_9_10481877_232FCWLT3_',
#  'HT1004_Solanum_SP5G_A05_Spim_2_9_10481877_232FCWLT3_',
#  'HT1004_Solanum_SP5G_A06_Spim_3_9_10481877_232FCWLT3_',
#  'HT1004_Solanum_SP5G_A07_BLANK_10481877_232FCWLT3_',
#  'HT1004_Solanum_SP5G_A08_Pgri_1_15_10481877_232FCWLT3_',
#  'HT1004_Solanum_SP5G_A09_Pgri_2_15_10481877_232FCWLT3_',
#  'HT1004_Solanum_SP5G_A10_Pgri_3_15_10481877_232FCWLT3_',
#  'HT1004_Solanum_SP5G_A11_Pgri_1_20_10481877_232FCWLT3_',
#  'HT1004_Solanum_SP5G_A12_Pgri_2_20_10481877_232FCWLT3_',
#  'HT1004_Solanum_SP5G_B01_M82_1_6_10481877_232FCWLT3_',
#  'HT1004_Solanum_SP5G_B02_M82_2_6_10481877_232FCWLT3_',
#  'HT1004_Solanum_SP5G_B03_M82_3_6_10481877_232FCWLT3_',
#  'HT1004_Solanum_SP5G_B04_M82_1_9_10481877_232FCWLT3_',
#  'HT1004_Solanum_SP5G_B05_M82_2_9_10481877_232FCWLT3_',
#  'HT1004_Solanum_SP5G_B06_M82_3_9_10481877_232FCWLT3_',
#  'HT1004_Solanum_SP5G_B07_Spim_1_15_10481877_232FCWLT3_',
#  'HT1004_Solanum_SP5G_B08_Spim_2_15_10481877_232FCWLT3_',
#  'HT1004_Solanum_SP5G_B09_Spim_3_15_10481877_232FCWLT3_',
#  'HT1004_Solanum_SP5G_B10_Spim_1_20_10481877_232FCWLT3_',
#  'HT1004_Solanum_SP5G_B11_Spim_2_20_10481877_232FCWLT3_',
#  'HT1004_Solanum_SP5G_B12_Spim_3_20_10481877_232FCWLT3_',
#  'HT1004_Solanum_SP5G_C01_Sang_1_6_10481877_232FCWLT3_',
#  'HT1004_Solanum_SP5G_C02_Sang_2_6_10481877_232FCWLT3_',
#  'HT1004_Solanum_SP5G_C03_Sang_3_6_10481877_232FCWLT3_',
#  'HT1004_Solanum_SP5G_C04_Sang_1_9_10481877_232FCWLT3_',
#  'HT1004_Solanum_SP5G_C05_Sang_2_9_10481877_232FCWLT3_',
#  'HT1004_Solanum_SP5G_C06_Sang_3_9_10481877_232FCWLT3_',
#  'HT1004_Solanum_SP5G_C07_M82_1_15_10481877_232FCWLT3_',
#  'HT1004_Solanum_SP5G_C08_M82_2_15_10481877_232FCWLT3_',
#  'HT1004_Solanum_SP5G_C09_M82_3_15_10481877_232FCWLT3_',
#  'HT1004_Solanum_SP5G_C10_M82_1_20_10481877_232FCWLT3_',
#  'HT1004_Solanum_SP5G_C11_M82_2_20_10481877_232FCWLT3_',
#  'HT1004_Solanum_SP5G_C12_M82_3_20_10481877_232FCWLT3_',
#  'HT1004_Solanum_SP5G_D01_Saet_1_6_10481877_232FCWLT3_',
#  'HT1004_Solanum_SP5G_D02_Saet_2_6_10481877_232FCWLT3_',
#  'HT1004_Solanum_SP5G_D03_Saet_3_6_10481877_232FCWLT3_',
#  'HT1004_Solanum_SP5G_D04_Saet_1_9_10481877_232FCWLT3_',
#  'HT1004_Solanum_SP5G_D05_Saet_2_9_10481877_232FCWLT3_',
#  'HT1004_Solanum_SP5G_D06_Saet_3_9_10481877_232FCWLT3_',
#  'HT1004_Solanum_SP5G_D07_Sang_1_15_10481877_232FCWLT3_',
#  'HT1004_Solanum_SP5G_D08_Sang_2_15_10481877_232FCWLT3_',
#  'HT1004_Solanum_SP5G_D09_Sang_3_15_10481877_232FCWLT3_',
#  'HT1004_Solanum_SP5G_D10_Sang_1_20_10481877_232FCWLT3_',
#  'HT1004_Solanum_SP5G_D11_Sang_2_20_10481877_232FCWLT3_',
#  'HT1004_Solanum_SP5G_D12_Sang_3_20_10481877_232FCWLT3_',
#  'HT1004_Solanum_SP5G_E01_SC103_1_6_10481877_232FCWLT3_',
#  'HT1004_Solanum_SP5G_E02_SC103_2_6_10481877_232FCWLT3_',
#  'HT1004_Solanum_SP5G_E03_SC103_3_6_10481877_232FCWLT3_',
#  'HT1004_Solanum_SP5G_E04_SC103_1_9_10481877_232FCWLT3_',
#  'HT1004_Solanum_SP5G_E05_SC103_2_9_10481877_232FCWLT3_',
#  'HT1004_Solanum_SP5G_E06_SC103_3_9_10481877_232FCWLT3_',
#  'HT1004_Solanum_SP5G_E07_Saet_1_15_10481877_232FCWLT3_',
#  'HT1004_Solanum_SP5G_E08_Saet_2_15_10481877_232FCWLT3_',
#  'HT1004_Solanum_SP5G_E09_Saet_3_15_10481877_232FCWLT3_',
#  'HT1004_Solanum_SP5G_E10_Saet_1_20_10481877_232FCWLT3_',
#  'HT1004_Solanum_SP5G_E11_Saet_2_20_10481877_232FCWLT3_',
#  'HT1004_Solanum_SP5G_E12_Saet_3_20_10481877_232FCWLT3_',
#  'HT1004_Solanum_SP5G_F01_Scle_1_6_10481877_232FCWLT3_',
#  'HT1004_Solanum_SP5G_F02_Scle_2_6_10481877_232FCWLT3_',
#  'HT1004_Solanum_SP5G_F03_Scle_3_6_10481877_232FCWLT3_',
#  'HT1004_Solanum_SP5G_F04_Scle_1_9_10481877_232FCWLT3_',
#  'HT1004_Solanum_SP5G_F05_Scle_2_9_10481877_232FCWLT3_',
#  'HT1004_Solanum_SP5G_F06_Scle_3_9_10481877_232FCWLT3_',
#  'HT1004_Solanum_SP5G_F07_SC103_1_15_10481877_232FCWLT3_',
#  'HT1004_Solanum_SP5G_F08_SC103_2_15_10481877_232FCWLT3_',
#  'HT1004_Solanum_SP5G_F09_SC103_3_15_10481877_232FCWLT3_',
#  'HT1004_Solanum_SP5G_F10_SC103_1_20_10481877_232FCWLT3_',
#  'HT1004_Solanum_SP5G_F11_SC103_2_20_10481877_232FCWLT3_',
#  'HT1004_Solanum_SP5G_F12_SC103_3_20_10481877_232FCWLT3_',
#  'HT1004_Solanum_SP5G_G01_Spri_1_6_10481877_232FCWLT3_',
#  'HT1004_Solanum_SP5G_G02_Spri_2_6_10481877_232FCWLT3_',
#  'HT1004_Solanum_SP5G_G03_Spri_3_6_10481877_232FCWLT3_',
#  'HT1004_Solanum_SP5G_G04_Spri_1_9_10481877_232FCWLT3_',
#  'HT1004_Solanum_SP5G_G06_Spri_3_9_10481877_232FCWLT3_',
#  'HT1004_Solanum_SP5G_G07_Scle_1_15_10481877_232FCWLT3_',
#  'HT1004_Solanum_SP5G_G08_Scle_2_15_10481877_232FCWLT3_',
#  'HT1004_Solanum_SP5G_G09_Scle_3_15_10481877_232FCWLT3_',
#  'HT1004_Solanum_SP5G_G10_Scle_1_20_10481877_232FCWLT3_',
#  'HT1004_Solanum_SP5G_G11_Scle_2_20_10481877_232FCWLT3_',
#  'HT1004_Solanum_SP5G_G12_Scle_3_20_10481877_232FCWLT3_',
#  'HT1004_Solanum_SP5G_H01_Pgri_1_6_10481877_232FCWLT3_',
#  'HT1004_Solanum_SP5G_H02_Pgri_2_6_10481877_232FCWLT3_',
#  'HT1004_Solanum_SP5G_H03_Pgri_3_6_10481877_232FCWLT3_',
#  'HT1004_Solanum_SP5G_H04_Pgri_1_10481877_232FCWLT3_',
#  'HT1004_Solanum_SP5G_H05_Pgri_2_9_10481877_232FCWLT3_',
#  'HT1004_Solanum_SP5G_H06_Pgri_3_9_10481877_232FCWLT3_',
#  'HT1004_Solanum_SP5G_H07_Spri_1_15_10481877_232FCWLT3_',
#  'HT1004_Solanum_SP5G_H08_Spri_2_15_10481877_232FCWLT3_',
#  'HT1004_Solanum_SP5G_H09_Spri_3_15_10481877_232FCWLT3_',
#  'HT1004_Solanum_SP5G_H10_Spri_1_20_10481877_232FCWLT3_',
#  'HT1004_Solanum_SP5G_H11_Spri_2_20_10481877_232FCWLT3_',
#  'HT1004_Solanum_SP5G_H12_Spri_3_20_10481877_232FCWLT3_',
#  'HT1004_Solanum_SP5G_G05_Spri_2_9_10481877_232FCWLT3_']

# %%
for file_prefix in list_of_unique_file_prefixes: 

    r1_file = file_location + file_prefix + 'L1_R1.fastq' 
    r2_file = file_location + file_prefix + 'L1_R2.fastq'
        if file_prefix == 'HT1004_Solanum_SP5G_A07_BLANK_10481877_232FCWLT3_': 
        ! /data/passala/Module_paper_data/Populus_vs_glycine_drought/STAR --runThreadN 30 --genomeDir /data/passala/Genomes/Solanum_lycopersicum_4_0 --readFilesIn {r1_file} {r2_file} --outSAMtype None --outFileNamePrefix {processed_data_location+file_prefix} --quantMode GeneCounts
        continue
    decoded_file_characteristics = decode_file_name(file_prefix)
    species = decoded_file_characteristics['species']
    genome_directory = genome_locations.loc[genome_locations['Abbreviation'] == species]['Genome Folder'].item()
    ! /data/passala/Module_paper_data/Populus_vs_glycine_drought/STAR --runThreadN 30 --genomeDir {genome_directory} --readFilesIn {r1_file} {r2_file} --outSAMtype None --outFileNamePrefix {processed_data_location+file_prefix} --quantMode GeneCounts
    break
# Out:
# Jul 04 10:17:07 ..... started STAR run
# Jul 04 10:17:07 ..... loading genome
# Jul 04 10:17:17 ..... started mapping
# Jul 04 10:20:58 ..... finished mapping
# Jul 04 10:20:59 ..... finished successfully

# %%
decode_file_name(list_of_files[0])
# Out:
# ['Spim', '1', '6am']
