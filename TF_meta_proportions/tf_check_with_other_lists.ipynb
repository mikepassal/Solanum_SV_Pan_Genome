# %%
import pandas as pd
import Go_annotations
import GO_Enrichment_Calculator
import matplotlib.pyplot as plt
import seaborn as sns

# %%
tomato_wgdd_list = pd.read_csv('/data/passala/Generated_Tables/Reference_tables/gene_pairs/pairs/Sly.wgd.pairs',sep = '\t')
tomato_wgdd_list
# Out:
#              Duplicate 1                 Location         Duplicate 2  \
# 0     Solyc00g007330.1.1   Sly-SL2.40ch00:7004447  Solyc00g012540.1.1
# 1     Solyc00g008030.1.1   Sly-SL2.40ch00:7554160  Solyc00g014170.1.1
# 2     Solyc00g008050.1.1   Sly-SL2.40ch00:7615934  Solyc00g014180.1.1
# 3     Solyc00g008130.1.1   Sly-SL2.40ch00:7679694  Solyc00g014190.1.1
# 4     Solyc00g008690.1.1   Sly-SL2.40ch00:8506115  Solyc00g015610.1.1
# ...                  ...                      ...                 ...
# 4104  Solyc12g049030.1.1  Sly-SL2.40ch12:45906133  Solyc12g100230.1.1
# 4105  Solyc12g049150.1.1  Sly-SL2.40ch12:46025362  Solyc12g100100.1.1
# 4106  Solyc12g049160.1.1  Sly-SL2.40ch12:46028509  Solyc12g100090.1.1
# 4107  Solyc12g049170.1.1  Sly-SL2.40ch12:46031528  Solyc12g100080.1.1
# 4108  Solyc12g049190.1.1  Sly-SL2.40ch12:46049874  Solyc12g099980.1.1
#
#                    Location.1        E-value
# 0     Sly-SL2.40ch00:10522603  8.000000e-162
# 1     Sly-SL2.40ch00:10915484   5.000000e-43
# 2     Sly-SL2.40ch00:10918360   2.000000e-21
# 3     Sly-SL2.40ch00:10934339   4.000000e-13
# 4     Sly-SL2.40ch00:11213131   4.000000e-26
# ...                       ...            ...
# 4104  Sly-SL2.40ch12:65365071   0.000000e+00
# 4105  Sly-SL2.40ch12:65296963   3.000000e-25
# 4106  Sly-SL2.40ch12:65294418  1.000000e-137
# 4107  Sly-SL2.40ch12:65292063   3.000000e-26
# 4108  Sly-SL2.40ch12:65246036   0.000000e+00
#
# [4109 rows x 5 columns]
