# %%
import pandas as pd
import CococoNet_reader

# %%
mustard = CococoNet_reader.read_cococonet('mustard')
rapeseed = CococoNet_reader.read_cococonet('rapeseed')

# %%
mustard
# Out:
#               LOC103854507  LOC103827501    EXPA20  LOC103845929  \
# LOC103854507      1.000000      0.863499  0.316904      0.227527
# LOC103827501      0.863499      1.000000  0.921235      0.365984
# EXPA20            0.316904      0.921235  1.000000      0.194132
# LOC103845929      0.227527      0.365984  0.194132      1.000000
# LOC103850518      0.829485      0.931780  0.752532      0.432679
# ...                    ...           ...       ...           ...
# LOC103848972      0.683649      0.961058  0.595987      0.338981
# LOC117131456      0.029121      0.425840  0.115132      0.012907
# LOC117131516      0.075608      0.322523  0.163296      0.046668
# LOC117131517      0.011286      0.152343  0.113062      0.087615
# LOC117131626      0.052695      0.171007  0.076634      0.038126
#
#               LOC103850518  LOC103851482  LOC103853645  LOC103844371  \
# LOC103854507      0.829485      0.522122      0.782395      0.749526
# ...

# %%
rapeseed
# Out:
#               LOC106345161  LOC106353279  LOC106434002  LOC106452042  \
# LOC106345161      1.000000      0.636610      0.359362      0.383490
# LOC106353279      0.636610      1.000000      0.659069      0.862125
# LOC106434002      0.359362      0.659069      1.000000      0.018974
# LOC106452042      0.383490      0.862125      0.018974      1.000000
# LOC106351011      0.372675      0.516489      0.178248      0.089234
# ...                    ...           ...           ...           ...
# LOC111214017     -0.911662      0.288905      0.369236      0.812847
# LOC111214018      0.911757      0.817582      0.361854      0.804869
# BrnapMr001        0.456260      0.354310      0.322585      0.375164
# BrnapMr002        0.717752      0.405755      0.339580      0.348635
# BrnapMr003        0.635577      0.296273      0.649536      0.272846
#
#               LOC106351011  LOC106360195  LOC106416206  LOC106416668  \
# ...
